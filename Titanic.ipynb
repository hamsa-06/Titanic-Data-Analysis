# %%
import pandas as pd
titan = pd.read_csv('Titanic.csv')
titan
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titan.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
titan.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titan.shape
# Out:
# (891, 12)

# %%
titan.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titan.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import matplotlib.pyplot as plt
survived = titan['Survived'].value_counts()
plt.pie(survived,labels=survived.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x79aba4fb6410>,
# ...
#  [Text(-0.3925749350994583, 1.0275626113924428, '0'),
#   Text(0.3925750313068116, -1.0275625746369201, '1')])

# %%
female = titan[titan.Sex=='female']

# %%
var = female.Pclass.value_counts()
var
# Out:
# Pclass
# 3    144
# 1     94
# 2     76
# Name: count, dtype: int64

# %%
plt.pie(var,labels=["3rd Class","1st Class","2nd Class"],autopct="%0.2f%%",explode=(0,0.1,0))
plt.show()

# %%
df_a = titan[(titan.Age<30) & (titan.Sex == 'female')]
res = df_a.Survived.value_counts()

# %%
plt.pie(res,labels = res.index,autopct="%0.2f%%",explode=(0.1,0.1))
plt.show()

# %%
plt.bar(res.index,res)
plt.show()

# %%
df_b = titan[(titan.Age>40) & (titan.Sex == 'male')]
res1 = df_b.Survived.value_counts()

# %%
plt.pie(res1,labels=res1.index,autopct="%0.2f%%")
plt.show()

# %%
import numpy as np

# %%
counts, bins,_= plt.hist(titan.Age, bins = 20, color = "pink", edgecolor = "blue", label = "Age bins")
bin_centers = (bins[:-1]+ bins[1:])/2
plt.plot(bin_centers, counts, marker = 'o', color="r", label = "Age Distribution")
plt.xticks(np.arange(0, 84, 4))
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %%
var3 = titan[titan['Survived']==1].Age

# %%
counts, bins,_= plt.hist(var3, bins = 20, color = "pink", edgecolor = "blue", label = "Age bins")
bin_centers = (bins[:-1]+ bins[1:])/2
plt.plot(bin_centers, counts, marker = 'o', color="r", label = "Age Distribution")
plt.xticks(np.arange(0, 84, 4))
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %%
var4 = titan[titan['Survived']==0].Age

# %%
counts, bins,_= plt.hist(var4, bins = 20, color = "pink", edgecolor = "purple", label = "Age bins")
bin_centers = (bins[:-1]+ bins[1:])/2
plt.plot(bin_centers, counts, marker = 'o', color="r", label = "Age Distribution")
plt.xticks(np.arange(0, 84, 4))
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %%
survived = titan[titan['Survived']==1]

# %%
import seaborn as sb

# %%
sb.countplot(x='Pclass',hue='Sex',data=survived)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
temp = titan.Pclass.value_counts()
data = dict(temp)
x = data.keys()
count = data.values()

# %%
val = []
for i in x:
  if i == 1:
    val.append('First Class')
  elif i == 2:
    val.append('Second Class')
  else:
    val.append('Third Class')

# %%
plt.bar(val,count)
plt.show()

# %%
survived = titan[titan['Survived']==1]

# %%
sb.countplot(x='Pclass',hue='Survived',data=titan)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
fig,axs = plt.subplots(1,2,figsize=(8,4))
sb.countplot(x='Pclass',hue='Sex',data=survived,ax=axs[0])
axs[0].set_title('Class Distributed By Sex For Survived')

axs[1].bar(val,count,color=['red','green','blue'])
axs[1].set_title("Passenger Class")
# Out:
# Text(0.5, 1.0, 'Passenger Class')

# %%
var = titan[(titan['Pclass']==3) & (titan['Sex']=='male')]

# %%
var1 = titan[(titan['Pclass']==1) & (titan['Sex']=='female')]

# %%
var.Survived.value_counts().plot(kind='bar',color=['r','g'])
# Out:
# <Axes: xlabel='Survived'>

# %%
var1.Survived.value_counts().plot(kind='bar',color=['g','b'])
# Out:
# <Axes: xlabel='Survived'>

# %%
female_First = titan[(titan['Sex']=='female') & (titan['Pclass']==1)]

# %%
female_First.Survived.value_counts()
# Out:
# Survived
# 1    91
# 0     3
# Name: count, dtype: int64

# %%
titan.Sex= titan.Sex.map({"male":1,"female":0})

# %%
titan.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
titan['Age']= titan['Age'].fillna(28)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
titan["Embarked"] = le.fit_transform(titan["Embarked"])
titan['Cabin'] = le.fit_transform(titan['Cabin'])

# %%
titan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    int64
#  11  Embarked     891 non-null    int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 83.7+ KB
